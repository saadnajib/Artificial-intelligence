# %%
import matplotlib.pyplot as plt 
import numpy as np
from scipy import misc, ndimage 
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
import glob
from keras.preprocessing.image import img_to_array
# %matplotlib inline

######################################################################

#plots images with Labels within jupyter notebook
def plots(ims,figsize=(12,6),rows=1,interp=False,titles=None):
    if type(ims[0]) is np.ndarray:
        ims = np.array(ims).astype(np.uint8)
        if(ims.shape[-1] != 3):
            ims=ims.transpose((0,2,3,1))
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows+1
    for i in range(len(ims)):
        sp = f.add_subplot(rows,cols,i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i],fontsize=16)
        plt.imshow(ims[i],interpolation=None if interp else 'none')

######################################################################        

#for i in range(1,11):
    
image_path =r'C:/Users/saad najib/Desktop/idenprof/test/saad/(2).jpg'
    
    #Obtain image
image = np.expand_dims(ndimage.imread(image_path),0)
plt.imshow(image[0])

######################################################################

gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1,height_shift_range=0.1,shear_range=0.15, zoom_range=0.1,channel_shift_range=10.,horizontal_flip=True)

aug_iter = gen.flow(image)
aug_images = [next(aug_iter)[0].astype(np.uint8) for i in range(51)]
plots(aug_images,figsize=(20,7),rows=5)

# example of saving an image with the Keras API
from keras.preprocessing.image import load_img
from keras.preprocessing.image import save_img
from keras.preprocessing.image import img_to_array

for i in range(51):
    
    save_img(r'C:/Users/saad najib/Desktop/idenprof/test/saad/a/test2'+str(i)+'.jpg',aug_images[i])
    # load the image to confirm it was saved correctly
    img = load_img(r'C:/Users/saad najib/Desktop/idenprof/test/saad/a/test2'+str(i)+'.jpg')
    print(type(img))
    print(img.format)
    print(img.mode)
    print(img.size)
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:35: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0.
# Use ``matplotlib.pyplot.imread`` instead.
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# JPEG
# RGB
# (979, 1166)
# ...
